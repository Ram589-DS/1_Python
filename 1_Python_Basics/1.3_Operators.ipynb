# %%
# Arthematic Operations

a=int(input("Enter the a value"))
b=int(input("Enter the b value"))

division = a/b
print("Division -> Quotient is : ",division)

floor_division = a//b # difference between division and floor division is it removes the decimal point 
modulus_res = a%b   # it gives you the reminder

print("Modulus operator -> Remainder :" , modulus_res)

exponent_res = a**b
print("Exponentail result is: " , exponent_res)
# Out:
# Division -> Quotient is :  6.0
# Modulus operator -> Remainder : 0
# Exponentail result is:  144

# %%
# difference between division and floor division is it will remove the decimal and after value and give the remaining result

# %%
# Comparision Operator
# == Operator
a = 10
b=10;
a==b
# Out:
# True

# %%
str1 = "Ram"
str2 = "Ram"
str1==str2
# Out:
# True

# %%
# Not equal to  , greater than > , lessthan < , 
str1!=str2
# Out:
# False

# %% [markdown]
# Logical Operator
